# %%
"""
This file was used to insert automate a .csv file data into a MySQL .db file format."""

# %%
import mysql.connector
import csv
import pandas as pd

# %%
# Use the comments below to set up the username and password strings for connection.
# username = "Enter your username here in this string."
# password = "Enter your password here in this string."

username = ""
password = ""

# %%
mydb = mysql.connector.connect(
    host = "localhost", 
    user = username, 
    passwd = password
)

print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x00000262C5E01E80>

# %%
mycursor = mydb.cursor()

# %%
mycursor.execute("CREATE DATABASE IF NOT EXISTS myworkouts")

# %%
mycursor.execute("SHOW DATABASES")

for x in mycursor:
    print(x)
# Out:
# ('employees',)
# ('employees_mod',)
# ('information_schema',)
# ('mysql',)
# ('myworkouts',)
# ('performance_schema',)
# ('sales',)
# ('sys',)

# %%
# mydb = mysql.connector.connect(
#     host = "localhost", 
#     user = username, 
#     passwd = password, 
#     db = "myworkouts"
# )

# %%
query = ("USE myworkouts")
mycursor.execute(query)

# %%
query = ("CREATE TABLE IF NOT EXISTS workouts "
"(workout_no INT PRIMARY KEY AUTO_INCREMENT, "
"exercise VARCHAR(255), "
"sets TINYINT UNSIGNED, "
"reps TINYINT UNSIGNED, "
"weight_lbs SMALLINT UNSIGNED, "
"date_time DATETIME, "
"duration_minutes SMALLINT)")

mycursor.execute(query)

# %%
query = 'DESCRIBE workouts'
mycursor.execute(query)

for x in mycursor:
    print(x)
# Out:
# ('workout_no', 'int(11)', 'NO', 'PRI', None, 'auto_increment')
# ('exercise', 'varchar(255)', 'YES', '', None, '')
# ('sets', 'tinyint(3) unsigned', 'YES', '', None, '')
# ('reps', 'tinyint(3) unsigned', 'YES', '', None, '')
# ('weight_lbs', 'smallint(5) unsigned', 'YES', '', None, '')
# ('date_time', 'datetime', 'YES', '', None, '')
# ('duration_minutes', 'smallint(6)', 'YES', '', None, '')

# %%
query = ("Select * FROM workouts")
mycursor.execute(query)
for x in mycursor:
    print(x)

# %%
workout_data = pd.read_csv("workout_data_database.csv")
workout_data.head()
# Out:
#    Unnamed: 0       exercise  sets  reps  weight_lbs             datetime  \
# 0           0     Clean&Jerk     3     7          65  2018-07-24 00:00:00
# 1           1     BenchPress     3     7          65  2018-07-24 00:00:00
# 2           2  ShoulderPress     2     7          65  2018-07-25 00:00:00
# 3           3  ShoulderPress     1    10          65  2018-07-25 00:00:00
# 4           4      BackSquat     3     5          65  2018-07-23 00:00:00
#
#    duration_minutes
# 0              -1.0
# 1              -1.0
# 2              -1.0
# 3              -1.0
# 4              -1.0

# %%
workout_data.drop(columns = ["Unnamed: 0"], inplace = True)
workout_data.head()
# Out:
#         exercise  sets  reps  weight_lbs             datetime  \
# 0     Clean&Jerk     3     7          65  2018-07-24 00:00:00
# 1     BenchPress     3     7          65  2018-07-24 00:00:00
# 2  ShoulderPress     2     7          65  2018-07-25 00:00:00
# 3  ShoulderPress     1    10          65  2018-07-25 00:00:00
# 4      BackSquat     3     5          65  2018-07-23 00:00:00
#
#    duration_minutes
# 0              -1.0
# 1              -1.0
# 2              -1.0
# 3              -1.0
# 4              -1.0

# %%
workout_data_tuple = [tuple(i) for i in workout_data.values.tolist()]
workout_data_tuple[0:5]
# Out:
# [('Clean&Jerk', 3, 7, 65, '2018-07-24 00:00:00', -1.0),
#  ('BenchPress', 3, 7, 65, '2018-07-24 00:00:00', -1.0),
#  ('ShoulderPress', 2, 7, 65, '2018-07-25 00:00:00', -1.0),
#  ('ShoulderPress', 1, 10, 65, '2018-07-25 00:00:00', -1.0),
#  ('BackSquat', 3, 5, 65, '2018-07-23 00:00:00', -1.0)]

# %%
query = """INSERT INTO workouts
(exercise, sets, reps, weight_lbs, date_time, duration_minutes)
VALUES (%s, %s, %s, %s, %s, %s)"""

for i in range(len(workout_data_tuple)):
    mycursor.execute(query, workout_data_tuple[i])

# %%
query = ("Select * FROM workouts")
mycursor.execute(query)
for x in mycursor:
    print(x)
# Out:
# (1, 'Clean&Jerk', 3, 7, 65, datetime.datetime(2018, 7, 24, 0, 0), -1)
# (2, 'BenchPress', 3, 7, 65, datetime.datetime(2018, 7, 24, 0, 0), -1)
# (3, 'ShoulderPress', 2, 7, 65, datetime.datetime(2018, 7, 25, 0, 0), -1)
# (4, 'ShoulderPress', 1, 10, 65, datetime.datetime(2018, 7, 25, 0, 0), -1)
# (5, 'BackSquat', 3, 5, 65, datetime.datetime(2018, 7, 23, 0, 0), -1)
# (6, 'BenchPress', 2, 7, 65, datetime.datetime(2018, 7, 28, 0, 0), -1)
# (7, 'BenchPress', 1, 8, 65, datetime.datetime(2018, 7, 28, 0, 0), -1)
# (8, 'Clean&Jerk', 2, 7, 65, datetime.datetime(2018, 7, 28, 0, 0), -1)
# (9, 'FrontSquat', 3, 7, 45, datetime.datetime(2018, 7, 29, 0, 0), -1)
# (10, 'OverheadSquat', 3, 3, 45, datetime.datetime(2018, 7, 29, 0, 0), -1)
# (11, 'Deadlift', 3, 7, 95, datetime.datetime(2018, 8, 1, 0, 0), -1)
# (12, 'ShoulderPress', 3, 7, 65, datetime.datetime(2018, 8, 1, 0, 0), -1)
# (13, 'Snatch', 3, 7, 65, datetime.datetime(2018, 8, 1, 0, 0), -1)
# (14, 'FrontSquat', 1, 6, 65, datetime.datetime(2018, 8, 4, 0, 0), 50)
# (15, 'FrontSquat', 1, 6, 75, datetime.datetime(2018, 8, 4, 0, 0), 50)
# (16, 'FrontSquat', 1, 6, 85, datetime.datetime(2018, 8, 4, 0, 0), 50)
# (17, 'ShoulderPress', 1, 8, 65, datetime.datetime(2018, 8, 4, 0, 0), 50)
# (18, 'ShoulderPress', 1, 7, 75, datetime.datetime(2018, 8, 4, 0, 0), 50)
# (19, 'ShoulderPress', 1, 5, 85, datetime.datetime(2018, 8, 4, 0, 0), 50)
# (20, 'BenchPress', 3, 8, 85, datetime.datetime(2018, 8, 4, 0, 0), 50)
# (21, 'Deadlift', 1, 8, 75, datetime.datetime(2018, 8, 5, 0, 0), -1)
# (22, 'Deadlift', 1, 8, 95, datetime.datetime(2018, 8, 5, 0, 0), -1)
# (23, 'Deadlift', 1, 8, 110, datetime.datetime(2018, 8, 5, 0, 0), -1)
# (24, 'BackSquat', 3, 7, 95, datetime.datetime(2018, 8, 7, 0, 0), -1)
# (25, 'ShoulderPress', 3, 7, 75, datetime.datetime(2018, 8, 11, 0, 0), -1)
# (26, 'BackSquat', 3, 7, 115, datetime.datetime(2018, 8, 11, 0, 0), -1)
# (27, 'Deadlift', 3, 5, 115, datetime.datetime(2018, 8, 12, 0, 0), -1)
# (28, 'FrontSquat', 3, 5, 95, datetime.datetime(2018, 8, 14, 0, 0), -1)
# (29, 'BenchPress', 3, 5, 115, datetime.datetime(2018, 8, 14, 0, 0), -1)
# (30, 'OverheadSquat', 3, 5, 45, datetime.datetime(2018, 8, 14, 0, 0), -1)
# (31, 'Clean&Jerk', 3, 5, 45, datetime.datetime(2018, 8, 15, 0, 0), -1)
# (32, 'Snatch', 3, 5, 45, datetime.datetime(2018, 8, 15, 0, 0), -1)
# (33, 'BackSquat', 3, 7, 135, datetime.datetime(2018, 8, 18, 0, 0), 55)
# (34, 'ShoulderPress', 1, 7, 75, datetime.datetime(2018, 8, 18, 0, 0), 55)
# (35, 'ShoulderPress', 1, 7, 85, datetime.datetime(2018, 8, 18, 0, 0), 55)
# (36, 'ShoulderPress', 1, 7, 95, datetime.datetime(2018, 8, 18, 0, 0), 55)
# (37, 'Deadlift', 3, 7, 135, datetime.datetime(2018, 8, 19, 0, 0), 60)
# (38, 'FrontSquat', 3, 5, 95, datetime.datetime(2018, 8, 20, 0, 0), -1)
# (39, 'BenchPress', 3, 5, 135, datetime.datetime(2018, 8, 20, 0, 0), -1)
# (40, 'ShoulderPress', 3, 5, 65, datetime.datetime(2018, 8, 21, 0, 0), -1)
# (41, 'BackSquat', 3, 7, 155, datetime.datetime(2018, 8, 25, 0, 0), -1)
# (42, 'ShoulderPress', 3, 7, 90, datetime.datetime(2018, 8, 25, 0, 0), -1)
# (43, 'Deadlift', 3, 5, 155, datetime.datetime(2018, 8, 26, 0, 0), -1)
# (44, 'FrontSquat', 3, 5, 95, datetime.datetime(2018, 8, 27, 0, 0), -1)
# (45, 'BenchPress', 3, 5, 135, datetime.datetime(2018, 8, 27, 0, 0), -1)
# (46, 'Clean&Jerk', 3, 3, 95, datetime.datetime(2018, 8, 28, 0, 0), -1)
# (47, 'BackSquat', 3, 5, 135, datetime.datetime(2018, 9, 1, 0, 0), -1)
# (48, 'ShoulderPress', 3, 5, 85, datetime.datetime(2018, 9, 1, 0, 0), -1)
# (49, 'Deadlift', 3, 5, 135, datetime.datetime(2018, 9, 2, 0, 0), -1)
# (50, 'OverheadSquat', 3, 5, 45, datetime.datetime(2018, 9, 3, 0, 0), -1)
# (51, 'FrontSquat', 3, 5, 95, datetime.datetime(2018, 9, 4, 0, 0), -1)
# (52, 'BenchPress', 3, 5, 125, datetime.datetime(2018, 9, 4, 0, 0), -1)
# (53, 'OverheadSquat', 3, 5, 45, datetime.datetime(2018, 9, 4, 0, 0), -1)
# (54, 'Deadlift', 2, 5, 185, datetime.datetime(2018, 9, 8, 0, 0), -1)
# (55, 'Deadlift', 1, 5, 205, datetime.datetime(2018, 9, 8, 0, 0), -1)
# (56, 'OverheadSquat', 1, 5, 45, datetime.datetime(2018, 9, 8, 0, 0), -1)
# (57, 'OverheadSquat', 1, 5, 55, datetime.datetime(2018, 9, 8, 0, 0), -1)
# (58, 'OverheadSquat', 1, 5, 65, datetime.datetime(2018, 9, 8, 0, 0), -1)
# (59, 'BackSquat', 1, 5, 205, datetime.datetime(2018, 9, 9, 0, 0), -1)
# (60, 'BackSquat', 2, 6, 205, datetime.datetime(2018, 9, 9, 0, 0), -1)
# (61, 'ShoulderPress', 2, 4, 115, datetime.datetime(2018, 9, 9, 0, 0), -1)
# (62, 'ShoulderPress', 1, 5, 115, datetime.datetime(2018, 9, 9, 0, 0), -1)
# (63, 'OverheadSquat', 3, 5, 45, datetime.datetime(2018, 9, 10, 0, 0), -1)
# (64, 'FrontSquat', 1, 5, 115, datetime.datetime(2018, 9, 11, 0, 0), -1)
# (65, 'FrontSquat', 1, 5, 125, datetime.datetime(2018, 9, 11, 0, 0), -1)
# (66, 'FrontSquat', 1, 8, 115, datetime.datetime(2018, 9, 11, 0, 0), -1)
# (67, 'BenchPress', 2, 5, 135, datetime.datetime(2018, 9, 11, 0, 0), -1)
# (68, 'BenchPress', 1, 4, 155, datetime.datetime(2018, 9, 11, 0, 0), -1)
# (69, 'BenchPress', 1, 3, 125, datetime.datetime(2018, 9, 15, 0, 0), -1)
# (70, 'BenchPress', 1, 3, 155, datetime.datetime(2018, 9, 15, 0, 0), -1)
# (71, 'BenchPress', 1, 3, 175, datetime.datetime(2018, 9, 15, 0, 0), -1)
# (72, 'OverheadSquat', 3, 3, 65, datetime.datetime(2018, 9, 15, 0, 0), -1)
# (73, 'ShoulderPress', 3, 3, 95, datetime.datetime(2018, 9, 16, 0, 0), -1)
# (74, 'FrontSquat', 3, 3, 95, datetime.datetime(2018, 9, 16, 0, 0), -1)
# (75, 'Snatch', 3, 1, 65, datetime.datetime(2018, 9, 17, 0, 0), -1)
# (76, 'BackSquat', 3, 3, 165, datetime.datetime(2018, 9, 18, 0, 0), -1)
# (77, 'Deadlift', 3, 3, 95, datetime.datetime(2018, 9, 18, 0, 0), -1)
# (78, 'OverheadSquat', 3, 4, 75, datetime.datetime(2018, 9, 29, 0, 0), -1)
# (79, 'BackSquat', 3, 4, 175, datetime.datetime(2018, 9, 30, 0, 0), -1)
# (80, 'Deadlift', 3, 4, 85, datetime.datetime(2018, 9, 30, 0, 0), -1)
# (81, 'Snatch', 4, 1, 65, datetime.datetime(2018, 10, 1, 0, 0), -1)
# (82, 'BenchPress', 4, 3, 135, datetime.datetime(2018, 10, 6, 0, 0), -1)
# (83, 'OverheadSquat', 4, 3, 85, datetime.datetime(2018, 10, 6, 0, 0), -1)
# (84, 'ShoulderPress', 4, 3, 85, datetime.datetime(2018, 10, 7, 0, 0), -1)
# (85, 'FrontSquat', 4, 3, 85, datetime.datetime(2018, 10, 7, 0, 0), -1)
# (86, 'Snatch', 4, 1, 85, datetime.datetime(2018, 10, 8, 0, 0), -1)
# (87, 'BackSquat', 4, 3, 175, datetime.datetime(2018, 10, 9, 0, 0), -1)
# (88, 'ShoulderPress', 4, 3, 85, datetime.datetime(2018, 10, 9, 0, 0), -1)
# (89, 'OverheadSquat', 4, 3, 75, datetime.datetime(2018, 10, 10, 0, 0), -1)
# (90, 'OverheadSquat', 3, 3, 65, datetime.datetime(2018, 10, 27, 0, 0), -1)
# (91, 'BackSquat', 3, 3, 155, datetime.datetime(2018, 10, 28, 0, 0), -1)
# (92, 'ShoulderPress', 3, 3, 85, datetime.datetime(2018, 10, 28, 0, 0), -1)
# (93, 'Snatch', 3, 3, 65, datetime.datetime(2018, 10, 29, 0, 0), -1)
# (94, 'Clean&Jerk', 3, 3, 65, datetime.datetime(2018, 10, 29, 0, 0), -1)
# (95, 'ShoulderPress', 3, 3, 105, datetime.datetime(2018, 11, 4, 0, 0), -1)
# (96, 'FrontSquat', 3, 3, 105, datetime.datetime(2018, 11, 4, 0, 0), -1)
# (97, 'BenchPress', 3, 3, 145, datetime.datetime(2018, 11, 5, 0, 0), -1)
# (98, 'OverheadSquat', 1, 3, 65, datetime.datetime(2018, 11, 5, 0, 0), -1)
# (99, 'OverheadSquat', 1, 3, 75, datetime.datetime(2018, 11, 5, 0, 0), -1)
# (100, 'OverheadSquat', 1, 3, 85, datetime.datetime(2018, 11, 5, 0, 0), -1)
# (101, 'BackSquat', 3, 3, 190, datetime.datetime(2018, 11, 10, 0, 0), -1)
# (102, 'ShoulderPress', 3, 3, 105, datetime.datetime(2018, 11, 10, 0, 0), -1)
# (103, 'FrontSquat', 3, 3, 100, datetime.datetime(2018, 11, 14, 0, 0), -1)
# (104, 'BenchPress', 3, 3, 135, datetime.datetime(2018, 11, 13, 0, 0), -1)
# (105, 'OverheadSquat', 3, 3, 75, datetime.datetime(2018, 11, 13, 0, 0), -1)
# (106, 'BackSquat', 4, 3, 205, datetime.datetime(2018, 11, 17, 0, 0), -1)
# (107, 'ShoulderPress', 4, 3, 105, datetime.datetime(2018, 11, 17, 0, 0), -1)
# (108, 'BenchPress', 4, 3, 145, datetime.datetime(2018, 11, 19, 0, 0), -1)
# (109, 'OverheadSquat', 4, 3, 65, datetime.datetime(2018, 11, 19, 0, 0), -1)
# (110, 'ShoulderPress', 4, 3, 105, datetime.datetime(2018, 11, 20, 0, 0), -1)
# (111, 'FrontSquat', 4, 3, 105, datetime.datetime(2018, 11, 20, 0, 0), -1)
# (112, 'FrontSquat', 3, 3, 90, datetime.datetime(2018, 11, 24, 0, 0), -1)
# (113, 'BenchPress', 3, 3, 125, datetime.datetime(2018, 11, 25, 0, 0), -1)
# (114, 'OverheadSquat', 3, 3, 75, datetime.datetime(2018, 11, 25, 0, 0), -1)
# (115, 'BackSquat', 3, 3, 165, datetime.datetime(2018, 11, 27, 0, 0), -1)
# (116, 'ShoulderPress', 3, 3, 95, datetime.datetime(2018, 11, 27, 0, 0), -1)
# (117, 'ShoulderPress', 3, 3, 115, datetime.datetime(2018, 12, 2, 0, 0), -1)
# (118, 'FrontSquat', 3, 3, 115, datetime.datetime(2018, 12, 2, 0, 0), -1)
# (119, 'BenchPress', 3, 3, 155, datetime.datetime(2018, 12, 3, 0, 0), -1)
# (120, 'OverheadSquat', 3, 3, 85, datetime.datetime(2018, 12, 3, 0, 0), -1)
# (121, 'Deadlift', 3, 3, 220, datetime.datetime(2018, 12, 4, 0, 0), -1)
# (122, 'BackSquat', 3, 10, 45, datetime.datetime(2018, 12, 4, 0, 0), -1)
# (123, 'BackSquat', 3, 3, 205, datetime.datetime(2018, 12, 5, 0, 0), -1)
# (124, 'ShoulderPress', 3, 3, 115, datetime.datetime(2018, 12, 5, 0, 0), -1)
# (125, 'ShoulderPress', 3, 8, 85, datetime.datetime(2018, 12, 8, 0, 0), -1)
# (126, 'FrontSquat', 3, 8, 85, datetime.datetime(2018, 12, 8, 0, 0), -1)
# (127, 'BenchPress', 3, 8, 115, datetime.datetime(2018, 12, 9, 0, 0), -1)
# (128, 'OverheadSquat', 3, 8, 45, datetime.datetime(2018, 12, 9, 0, 0), -1)
# (129, 'Deadlift', 3, 8, 170, datetime.datetime(2018, 12, 10, 0, 0), -1)
# (130, 'BackSquat', 3, 8, 145, datetime.datetime(2018, 12, 11, 0, 0), -1)
# (131, 'ShoulderPress', 3, 8, 85, datetime.datetime(2018, 12, 11, 0, 0), -1)
# (132, 'BenchPress', 1, 4, 90, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (133, 'BenchPress', 1, 3, 125, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (134, 'BenchPress', 1, 2, 160, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (135, 'BenchPress', 1, 6, 165, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (136, 'BackSquat', 1, 4, 120, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (137, 'BackSquat', 1, 3, 165, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (138, 'BackSquat', 1, 2, 210, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (139, 'BackSquat', 1, 7, 220, datetime.datetime(2018, 12, 15, 0, 0), -1)
# (140, 'Deadlift', 1, 4, 130, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (141, 'Deadlift', 1, 3, 180, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (142, 'Deadlift', 1, 2, 235, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (143, 'Deadlift', 1, 10, 240, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (144, 'Deadlift', 1, 4, 65, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (145, 'Deadlift', 1, 3, 95, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (146, 'Deadlift', 1, 2, 120, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (147, 'Deadlift', 1, 4, 125, datetime.datetime(2018, 12, 16, 0, 0), -1)
# (148, 'OverheadSquat', 1, 4, 45, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (149, 'OverheadSquat', 1, 3, 65, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (150, 'OverheadSquat', 1, 2, 95, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (151, 'OverheadSquat', 1, 5, 105, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (152, 'FrontSquat', 1, 4, 65, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (153, 'FrontSquat', 1, 3, 95, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (154, 'FrontSquat', 1, 2, 125, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (155, 'FrontSquat', 1, 10, 135, datetime.datetime(2018, 12, 18, 0, 0), -1)
# (156, 'Snatch', 1, 4, 45, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (157, 'Snatch', 1, 3, 65, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (158, 'Snatch', 1, 2, 75, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (159, 'Snatch', 1, 1, 95, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (160, 'Clean&Jerk', 1, 4, 65, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (161, 'Clean&Jerk', 1, 3, 85, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (162, 'Clean&Jerk', 1, 2, 105, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (163, 'Clean&Jerk', 1, 1, 125, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (164, 'Clean&Jerk', 1, 1, 135, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (165, 'Clean&Jerk', 1, 1, 145, datetime.datetime(2018, 12, 20, 0, 0), -1)
# (166, 'BackSquat', 3, 8, 185, datetime.datetime(2019, 1, 7, 0, 0), -1)
# (167, 'ShoulderPress', 3, 8, 95, datetime.datetime(2019, 1, 7, 0, 0), -1)
# (168, 'FrontSquat', 3, 8, 115, datetime.datetime(2019, 1, 8, 0, 0), -1)
# (169, 'BenchPress', 3, 8, 125, datetime.datetime(2019, 1, 8, 0, 0), -1)
# (170, 'OverheadSquat', 3, 8, 75, datetime.datetime(2019, 1, 10, 0, 0), -1)
# (171, 'Deadlift', 3, 8, 210, datetime.datetime(2019, 1, 10, 0, 0), -1)
# (172, 'Snatch', 3, 8, 45, datetime.datetime(2019, 1, 10, 0, 0), -1)
# (173, 'BackSquat', 3, 7, 185, datetime.datetime(2019, 1, 12, 0, 0), -1)
# (174, 'ShoulderPress', 3, 7, 100, datetime.datetime(2019, 1, 13, 0, 0), -1)
# (175, 'OverheadSquat', 3, 7, 75, datetime.datetime(2019, 1, 13, 0, 0), -1)
# (176, 'FrontSquat', 3, 7, 125, datetime.datetime(2019, 1, 14, 0, 0), -1)
# (177, 'BenchPress', 3, 7, 135, datetime.datetime(2019, 1, 15, 0, 0), -1)
# (178, 'Deadlift', 3, 7, 225, datetime.datetime(2019, 1, 16, 0, 0), -1)
# (179, 'Snatch', 1, 7, 45, datetime.datetime(2019, 1, 16, 0, 0), -1)
# (180, 'Snatch', 1, 7, 65, datetime.datetime(2019, 1, 16, 0, 0), -1)
# (181, 'Snatch', 1, 10, 45, datetime.datetime(2019, 1, 16, 0, 0), -1)
# (182, 'BackSquat', 4, 5, 205, datetime.datetime(2019, 1, 19, 0, 0), -1)
# (183, 'ShoulderPress', 4, 5, 105, datetime.datetime(2019, 1, 20, 0, 0), -1)
# (184, 'OverheadSquat', 4, 5, 75, datetime.datetime(2019, 1, 20, 0, 0), -1)
# (185, 'FrontSquat', 4, 5, 135, datetime.datetime(2019, 1, 21, 0, 0), -1)
# (186, 'BenchPress', 4, 5, 145, datetime.datetime(2019, 1, 22, 0, 0), -1)
# (187, 'Deadlift', 4, 5, 245, datetime.datetime(2019, 1, 23, 0, 0), -1)
# (188, 'Snatch', 4, 5, 45, datetime.datetime(2019, 1, 23, 0, 0), -1)
# (189, 'BackSquat', 5, 5, 160, datetime.datetime(2019, 1, 27, 0, 0), -1)
# (190, 'ShoulderPress', 5, 5, 85, datetime.datetime(2019, 1, 28, 0, 0), -1)
# (191, 'OverheadSquat', 2, 5, 75, datetime.datetime(2019, 1, 28, 0, 0), -1)
# (192, 'OverheadSquat', 3, 7, 45, datetime.datetime(2019, 1, 28, 0, 0), -1)
# (193, 'FrontSquat', 1, 5, 105, datetime.datetime(2019, 1, 28, 0, 0), -1)
# (194, 'FrontSquat', 4, 5, 110, datetime.datetime(2019, 1, 28, 0, 0), -1)
# (195, 'BenchPress', 5, 5, 120, datetime.datetime(2019, 1, 29, 0, 0), -1)
# (196, 'Deadlift', 5, 5, 195, datetime.datetime(2019, 1, 30, 0, 0), -1)
# (197, 'Snatch', 2, 5, 45, datetime.datetime(2019, 1, 30, 0, 0), -1)
# (198, 'Snatch', 1, 5, 65, datetime.datetime(2019, 1, 30, 0, 0), -1)
# (199, 'Snatch', 1, 5, 75, datetime.datetime(2019, 1, 30, 0, 0), -1)
# (200, 'Snatch', 1, 5, 85, datetime.datetime(2019, 1, 30, 0, 0), -1)
# (201, 'BackSquat', 4, 5, 205, datetime.datetime(2019, 2, 2, 0, 0), -1)
# (202, 'ShoulderPress', 4, 5, 105, datetime.datetime(2019, 2, 3, 0, 0), -1)
# (203, 'OverheadSquat', 4, 5, 65, datetime.datetime(2019, 2, 3, 0, 0), -1)
# (204, 'FrontSquat', 4, 5, 140, datetime.datetime(2019, 2, 4, 0, 0), -1)
# (205, 'BenchPress', 4, 5, 155, datetime.datetime(2019, 2, 5, 0, 0), -1)
# (206, 'Snatch', 1, 5, 45, datetime.datetime(2019, 2, 6, 0, 0), -1)
# (207, 'Snatch', 1, 5, 65, datetime.datetime(2019, 2, 6, 0, 0), -1)
# (208, 'Snatch', 1, 5, 75, datetime.datetime(2019, 2, 6, 0, 0), -1)
# (209, 'Snatch', 1, 5, 85, datetime.datetime(2019, 2, 6, 0, 0), -1)
# (210, 'BackSquat', 4, 4, 215, datetime.datetime(2019, 2, 10, 0, 0), 60)
# (211, 'ShoulderPress', 4, 4, 115, datetime.datetime(2019, 2, 11, 0, 0), 90)
# (212, 'OverheadSquat', 4, 4, 75, datetime.datetime(2019, 2, 11, 0, 0), 90)
# (213, 'FrontSquat', 4, 4, 145, datetime.datetime(2019, 2, 12, 0, 0), 90)
# (214, 'BenchPress', 4, 4, 160, datetime.datetime(2019, 2, 13, 19, 15), -1)
# (215, 'Snatch', 1, 4, 65, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (216, 'Snatch', 1, 4, 75, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (217, 'Snatch', 1, 4, 85, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (218, 'Snatch', 1, 4, 95, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (219, 'Clean&Jerk', 1, 4, 65, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (220, 'Clean&Jerk', 1, 4, 75, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (221, 'Clean&Jerk', 1, 4, 85, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (222, 'Clean&Jerk', 1, 4, 95, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (223, 'Deadlift', 1, 4, 185, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (224, 'Deadlift', 1, 4, 205, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (225, 'Deadlift', 1, 4, 225, datetime.datetime(2019, 2, 14, 0, 0), -1)
# (226, 'Clean&Jerk', 1, 4, 65, datetime.datetime(2019, 2, 16, 9, 1), -1)
# (227, 'Clean&Jerk', 1, 4, 75, datetime.datetime(2019, 2, 16, 9, 1), -1)
# (228, 'Clean&Jerk', 1, 4, 85, datetime.datetime(2019, 2, 16, 9, 1), -1)
# (229, 'BackSquat', 5, 5, 140, datetime.datetime(2019, 2, 16, 9, 1), -1)
# (230, 'ShoulderPress', 5, 5, 75, datetime.datetime(2019, 2, 17, 9, 5), -1)
# (231, 'OverheadSquat', 5, 5, 45, datetime.datetime(2019, 2, 17, 9, 5), -1)
# (232, 'Snatch', 1, 2, 65, datetime.datetime(2019, 2, 17, 9, 5), -1)
# (233, 'Snatch', 1, 2, 75, datetime.datetime(2019, 2, 17, 9, 5), -1)
# (234, 'Snatch', 1, 2, 85, datetime.datetime(2019, 2, 17, 9, 5), -1)
# (235, 'FrontSquat', 5, 5, 95, datetime.datetime(2019, 2, 18, 17, 30), 70)
# (236, 'BenchPress', 5, 5, 100, datetime.datetime(2019, 2, 19, 20, 15), 85)
# (237, 'OverheadSquat', 2, 5, 45, datetime.datetime(2019, 2, 19, 20, 15), 85)
# (238, 'OverheadSquat', 2, 5, 75, datetime.datetime(2019, 2, 19, 20, 15), 85)
# (239, 'OverheadSquat', 1, 5, 85, datetime.datetime(2019, 2, 19, 20, 15), 85)
# (240, 'Snatch', 1, 2, 75, datetime.datetime(2019, 2, 19, 20, 15), 85)
# (241, 'Snatch', 1, 2, 85, datetime.datetime(2019, 2, 19, 20, 15), 85)
# (242, 'Snatch', 1, 2, 95, datetime.datetime(2019, 2, 19, 20, 15), 85)
# (243, 'Deadlift', 1, 5, 115, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (244, 'Deadlift', 1, 3, 135, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (245, 'Deadlift', 1, 3, 155, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (246, 'Deadlift', 1, 3, 185, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (247, 'Deadlift', 1, 3, 205, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (248, 'Snatch', 1, 2, 45, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (249, 'Snatch', 1, 2, 65, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (250, 'Snatch', 3, 2, 75, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (251, 'Clean&Jerk', 1, 2, 45, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (252, 'Clean&Jerk', 1, 2, 65, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (253, 'Clean&Jerk', 3, 2, 75, datetime.datetime(2019, 2, 20, 20, 30), 80)
# (254, 'BackSquat', 3, 5, 210, datetime.datetime(2019, 2, 23, 15, 0), 105)
# (255, 'Clean&Jerk', 1, 4, 75, datetime.datetime(2019, 2, 23, 15, 0), 105)
# (256, 'Clean&Jerk', 1, 4, 85, datetime.datetime(2019, 2, 23, 15, 0), 105)
# (257, 'Clean&Jerk', 1, 4, 95, datetime.datetime(2019, 2, 23, 15, 0), 105)
# (258, 'ShoulderPress', 3, 5, 115, datetime.datetime(2019, 2, 24, 17, 5), 70)
# (259, 'OverheadSquat', 1, 5, 75, datetime.datetime(2019, 2, 24, 17, 5), 70)
# (260, 'OverheadSquat', 1, 5, 85, datetime.datetime(2019, 2, 24, 17, 5), 70)
# (261, 'OverheadSquat', 1, 5, 95, datetime.datetime(2019, 2, 24, 17, 5), 70)
# (262, 'Snatch', 1, 4, 75, datetime.datetime(2019, 2, 24, 17, 5), 70)
# (263, 'Snatch', 1, 4, 85, datetime.datetime(2019, 2, 24, 17, 5), 70)
# (264, 'Snatch', 1, 4, 95, datetime.datetime(2019, 2, 24, 17, 5), 70)
# (265, 'FrontSquat', 2, 5, 135, datetime.datetime(2019, 2, 25, 18, 20), 90)
# (266, 'FrontSquat', 1, 5, 145, datetime.datetime(2019, 2, 25, 18, 20), 90)
# (267, 'FrontSquat', 1, 5, 155, datetime.datetime(2019, 2, 25, 18, 20), 90)
# (268, 'BenchPress', 3, 5, 155, datetime.datetime(2019, 2, 26, 17, 50), 111)
# (269, 'OverheadSquat', 1, 5, 45, datetime.datetime(2019, 2, 26, 17, 50), 111)
# (270, 'OverheadSquat', 1, 5, 65, datetime.datetime(2019, 2, 26, 17, 50), 111)
# (271, 'OverheadSquat', 1, 5, 75, datetime.datetime(2019, 2, 26, 17, 50), 111)
# (272, 'Deadlift', 1, 5, 155, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (273, 'Deadlift', 1, 5, 185, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (274, 'Deadlift', 1, 5, 205, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (275, 'Snatch', 1, 2, 45, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (276, 'Snatch', 1, 2, 65, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (277, 'Snatch', 1, 2, 75, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (278, 'Snatch', 1, 2, 85, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (279, 'Snatch', 1, 2, 95, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (280, 'Clean&Jerk', 1, 2, 45, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (281, 'Clean&Jerk', 1, 2, 65, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (282, 'Clean&Jerk', 1, 2, 75, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (283, 'Clean&Jerk', 1, 2, 85, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (284, 'Clean&Jerk', 1, 2, 95, datetime.datetime(2019, 2, 27, 18, 21), -1)
# (285, 'BackSquat', 3, 4, 225, datetime.datetime(2019, 3, 10, 22, 38), 50)
# (286, 'BackSquat', 3, 4, 225, datetime.datetime(2019, 3, 18, 12, 30), 60)
# (287, 'ShoulderPress', 3, 4, 115, datetime.datetime(2019, 3, 19, 14, 40), -1)
# (288, 'Clean&Jerk', 3, 2, 95, datetime.datetime(2019, 3, 10, 22, 38), -1)
# (289, 'BackSquat', 3, 5, 215, datetime.datetime(2019, 3, 23, 17, 30), 75)
# (290, 'BackSquat', 3, 5, 215, datetime.datetime(2019, 3, 30, 13, 0), 90)
# (291, 'ShoulderPress', 3, 5, 115, datetime.datetime(2019, 3, 24, 15, 15), 65)
# (292, 'FrontSquat', 3, 5, 135, datetime.datetime(2019, 4, 2, 18, 15), -1)
# (293, 'ShoulderPress', 3, 5, 115, datetime.datetime(2019, 3, 31, 20, 15), 75)
# (294, 'OverheadSquat', 3, 5, 75, datetime.datetime(2019, 4, 2, 18, 15), -1)
# (295, 'BenchPress', 5, 10, 95, datetime.datetime(2019, 9, 3, 16, 15), 72)
# (296, 'Deadlift', 5, 10, 95, datetime.datetime(2019, 9, 3, 16, 15), 72)
# (297, 'BackSquat', 5, 10, 95, datetime.datetime(2019, 9, 2, 12, 16), 57)
# (298, 'OverheadSquat', 3, 10, 45, datetime.datetime(2019, 9, 4, 11, 25), 60)
# (299, 'SnatchPress', 3, 10, 65, datetime.datetime(2019, 9, 4, 11, 25), 60)
# (300, 'Deadlift', 5, 10, 95, datetime.datetime(2019, 9, 5, 11, 15), 75)
# (301, 'ShoulderPress', 4, 10, 65, datetime.datetime(2019, 9, 6, 10, 20), 65)
# (302, 'Deadlift', 5, 10, 95, datetime.datetime(2019, 9, 9, 11, 50), 75)
# (303, 'BenchPress', 5, 10, 95, datetime.datetime(2019, 9, 9, 11, 50), 75)
# (304, 'BackSquat', 5, 10, 95, datetime.datetime(2019, 9, 10, 10, 25), 73)
# (305, 'OverheadSquat', 3, 10, 65, datetime.datetime(2019, 9, 11, 11, 15), 70)
# (306, 'ShoulderPress', 3, 10, 65, datetime.datetime(2019, 9, 13, 10, 5), 58)
# (307, 'Deadlift', 5, 10, 95, datetime.datetime(2019, 9, 12, 11, 5), 85)
# (308, 'Deadlift', 5, 10, 95, datetime.datetime(2019, 9, 16, 10, 0), 60)
# (309, 'BenchPress', 5, 10, 95, datetime.datetime(2019, 9, 16, 10, 0), 60)
# (310, 'BackSquat', 5, 10, 95, datetime.datetime(2019, 9, 19, 22, 40), 59)
# (311, 'OverheadSquat', 3, 10, 45, datetime.datetime(2019, 9, 17, 22, 0), 58)
# (312, 'ShoulderPress', 3, 10, 65, datetime.datetime(2019, 9, 20, 16, 22), 53)
# (313, 'FrontSquat', 3, 10, 65, datetime.datetime(2019, 9, 20, 16, 22), 53)
# (314, 'BenchPress', 5, 10, 105, datetime.datetime(2019, 9, 23, 10, 3), 62)
# (315, 'BackSquat', 5, 10, 105, datetime.datetime(2019, 9, 25, 16, 5), 63)
# (316, 'BenchPress', 5, 10, 105, datetime.datetime(2019, 10, 7, 12, 45), -1)
# (317, 'BackSquat', 5, 10, 105, datetime.datetime(2019, 10, 9, 9, 40), 70)
# (318, 'SnatchPress', 4, 10, 65, datetime.datetime(2019, 10, 8, 14, 45), 75)
# (319, 'FrontSquat', 3, 10, 75, datetime.datetime(2019, 10, 10, 10, 15), 75)
# (320, 'ShoulderPress', 3, 10, 75, datetime.datetime(2019, 10, 10, 10, 15), 75)
# (321, 'BackSquat', 5, 10, 105, datetime.datetime(2019, 10, 30, 13, 25), 80)
# (322, 'BenchPress', 5, 10, 105, datetime.datetime(2019, 10, 30, 13, 25), 80)
# (323, 'OverheadSquat', 1, 10, 65, datetime.datetime(2019, 11, 1, 11, 0), 90)
# (324, 'OverheadSquat', 1, 10, 75, datetime.datetime(2019, 11, 1, 11, 0), 90)
# (325, 'OverheadSquat', 1, 10, 85, datetime.datetime(2019, 11, 1, 11, 0), 90)
# (326, 'FrontSquat', 5, 10, 75, datetime.datetime(2019, 10, 31, 22, 50), 80)
# (327, 'ShoulderPress', 5, 10, 75, datetime.datetime(2019, 10, 31, 22, 50), 80)
# (328, 'FrontSquat', 3, 10, 85, datetime.datetime(2019, 11, 2, 11, 8), 87)
# (329, 'BackSquat', 5, 10, 105, datetime.datetime(2019, 11, 5, 9, 40), 55)
# (330, 'BenchPress', 5, 10, 105, datetime.datetime(2019, 11, 5, 9, 40), 55)
# (331, 'FrontSquat', 5, 10, 75, datetime.datetime(2019, 11, 6, 10, 40), 85)
# (332, 'ShoulderPress', 5, 10, 75, datetime.datetime(2019, 11, 6, 10, 40), 85)
# (333, 'BackSquat', 5, 10, 105, datetime.datetime(2019, 11, 12, 13, 45), 90)
# (334, 'BenchPress', 5, 10, 105, datetime.datetime(2019, 11, 12, 13, 45), 90)
# (335, 'ShoulderPress', 5, 10, 75, datetime.datetime(2019, 11, 13, 15, 45), 75)
# (336, 'FrontSquat', 5, 10, 75, datetime.datetime(2019, 11, 13, 15, 45), 75)
# (337, 'SnatchPress', 1, 10, 65, datetime.datetime(2019, 11, 15, 11, 35), 123)
# (338, 'SnatchPress', 1, 10, 75, datetime.datetime(2019, 11, 15, 11, 35), 123)
# (339, 'SnatchPress', 1, 10, 85, datetime.datetime(2019, 11, 15, 11, 35), 123)
# (340, 'OverheadSquat', 1, 10, 65, datetime.datetime(2019, 11, 15, 11, 35), 123)
# (341, 'OverheadSquat', 1, 10, 75, datetime.datetime(2019, 11, 15, 11, 35), 123)
# (342, 'OverheadSquat', 1, 10, 85, datetime.datetime(2019, 11, 15, 11, 35), 123)
# (343, 'BackSquat', 5, 10, 115, datetime.datetime(2019, 11, 18, 11, 46), 74)
# (344, 'OverheadSquat', 1, 10, 75, datetime.datetime(2019, 11, 20, 10, 50), 75)
# (345, 'OverheadSquat', 1, 10, 85, datetime.datetime(2019, 11, 20, 10, 50), 75)
# (346, 'OverheadSquat', 1, 10, 95, datetime.datetime(2019, 11, 20, 10, 50), 75)
# (347, 'ShoulderPress', 5, 10, 85, datetime.datetime(2019, 11, 21, 18, 15), 64)

# %%
mydb.commit()
